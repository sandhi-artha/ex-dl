# %% [markdown]
# # ideal image resolution target?
# concluded: most are horizontal image with 640 width. some are very small res. let's take 480 by 480

# %%
# %cd ../
# Out:
# d:\Projects\python\ex-dl\6

# %%
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval
import os, json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2

from src.cfg import cfg

# %%
coco_gt = COCO(cfg.label_fp)
image_ids = coco_gt.getImgIds()
print(f'total images: {len(image_ids)}')
# Out:
# loading annotations into memory...
# Done (t=1.29s)
# creating index...
# index created!
# total images: 5000

# %%
heights = []
widths = []
for image_id in image_ids:
    image_info = coco_gt.imgs[image_id]
    heights.append(image_info['height'])
    widths.append(image_info['width'])

# %%
def get_stats(arr):
    print(f'max : {np.max(arr)}')
    print(f'min : {np.min(arr)}')
    print(f'mean : {np.mean(arr)}')
    print(f'median : {np.median(arr)}')

# %%
heights = np.array(heights)
widths = np.array(widths)

get_stats(heights)
get_stats(widths)
# Out:
# max : 640
# min : 145
# mean : 483.543
# median : 480.0
# max : 640
# min : 200
# mean : 573.7548
# median : 640.0

# %%
plt.scatter(widths, heights)
plt.xlabel('width')
plt.xlabel('height')

# %%
plt.hist(widths)
# Out:
# (array([   5.,    6.,   33.,  191.,   69.,  442.,  955.,   44.,   23.,
#         3232.]),
#  array([200., 244., 288., 332., 376., 420., 464., 508., 552., 596., 640.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(heights)
# Out:
# (array([  13.,   24.,   28.,  213.,  447., 1436., 1319.,  291.,   31.,
#         1198.]),
#  array([145. , 194.5, 244. , 293.5, 343. , 392.5, 442. , 491.5, 541. ,
#         590.5, 640. ]),
#  <BarContainer object of 10 artists>)
